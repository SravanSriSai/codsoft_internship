# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/sms-spam-collection-dataset/spam.csv

# %% [markdown]
# ### Data loading

# %%
# df = pd.read_csv('/kaggle/input/sms-spam-collection-dataset/spam.csv')
df = pd.read_csv('/kaggle/input/sms-spam-collection-dataset/spam.csv', encoding="latin1")

# %% [markdown]
# ### Data preprocessing

# %%
df.head()
# Out:
#      v1  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                             v2  \
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
pd.set_option('display.max_colwidth', None)

# %%
print(df[df['Unnamed: 2'].notna()][['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']])
# Out:
#         v1  \
# 95    spam
# 281    ham
# 444    ham
# 671   spam
# 710    ham
# 899   spam
# 1038   ham
# 1127   ham
# 1266   ham
# 1384   ham
# 1428   ham
# 1559   ham
# 1637  spam
# 1669   ham
# 1675   ham
# 1936   ham
# 1937   ham
# 1997   ham
# 2087   ham
# 2170   ham
# 2235   ham
# 2255   ham
# 2406   ham
# 2791   ham
# 2970   ham
# 3110   ham
# 3145   ham
# 3239   ham
# 3506   ham
# 3525   ham
# 3547   ham
# 3640  spam
# 3758   ham
# 3788   ham
# 3793   ham
# 3881   ham
# 4130   ham
# 4224   ham
# 4454   ham
# 4455   ham
# 4570   ham
# 4601   ham
# 4668   ham
# 4859   ham
# 4992   ham
# 5048   ham
# 5079   ham
# 5081   ham
# 5264   ham
# 5268   ham
#
#                                                                                                                                                                                                                                                                                           v2  \
# 95                                                                                                                                                             Your free ringtone is waiting to be collected. Simply text the password \MIX\" to 85069 to verify. Get Usher and Britney. FML
# 281                                                                                                                                                                                                                                                                      \Wen u miss someone
# 444                                                                                                                                                                                                                       \HEY HEY WERETHE MONKEESPEOPLE SAY WE MONKEYAROUND! HOWDY GORGEOUS
# 671                                                                                                                                                                                                                                               SMS. ac sun0819 posts HELLO:\You seem cool
# 710            Height of Confidence: All the Aeronautics professors wer calld &amp; they wer askd 2 sit in an aeroplane. Aftr they sat they wer told dat the plane ws made by their students. Dey all hurried out of d plane.. Bt only 1 didnt move... He said:\if it is made by my students
# 899                                                                                                                                                            Your free ringtone is waiting to be collected. Simply text the password \MIX\" to 85069 to verify. Get Usher and Britney. FML
# 1038                                                                                                                                         Edison has rightly said, \A fool can ask more questions than a wise man can answer\" Now you know why all of us are speechless during ViVa.. GM
# 1127                                                                                                                                                                      Height of \Oh shit....!!\" situation: A guy throws a luv letter on a gal but falls on her brothers head whos a gay
# 1266                                                                                                                                                                                                                                         \Hey sorry I didntgive ya a a bellearlier hunny
# 1384  Storming msg: Wen u lift d phne, u say \HELLO\" Do u knw wt is d real meaning of HELLO?? . . . It's d name of a girl..! . . . Yes.. And u knw who is dat girl?? \"Margaret Hello\" She is d girlfrnd f Grahmbell who invnted telphone... . . . . Moral:One can 4get d name of a person
# 1428                                                                                                                               Tell you what, if you make a little spreadsheet and track whose idea it was to smoke to determine who \smokes too much\" for the entire month of february
# 1559                                                                                                                                                                                                               Single line with a big meaning::::: \Miss anything 4 ur \"Best Life\" but
# 1637                                                                                                                                                                                             0A$NETWORKS allow companies to bill for SMS, so they are responsible for their \suppliers\"
# 1669                                                                                                                                                                                                             Very hurting n meaningful lines ever: \I compromised everything for my love
# 1675                                                                                                                                                                                                       Painful words- \I thought being Happy was the most toughest thing on Earth... But
# 1936                                                                                                                                                                                                                                           My planning usually stops at \find hella weed
# 1937                                                                                                                                                                              The fact that you're cleaning shows you know why i'm upset. Your priority is constantly \what i want to do
# 1997                                                                                                                                                                                                                                                         \YEH I AM DEF UP4 SOMETHING SAT
# 2087                                                                                                                                                                                                                                                                           \alright babe
# 2170                                                                                                                                                                                                                         \CAN I PLEASE COME UP NOW IMIN TOWN.DONTMATTER IF URGOIN OUTL8R
# 2235                                                                                                                                                \Si.como no?!listened2the plaid album-quite gd&the new air1 which is hilarious-also boughtåÓbraindanceåÓa comp.ofstuff on aphexåÕs ;abel
# 2255                                                                                                                                                                                                                                           I just lov this line: \Hurt me with the truth
# 2406                                                                                                                                                                                                                                   One of best dialogue in cute reltnship..!! \Wen i Die
# 2791                                                                                                                                                           Û_ we r stayin here an extra week, back next wed. How did we do in the rugby this weekend? Hi to and and , c u soon \"\rham"
# 2970           Height of Confidence: All the Aeronautics professors wer calld &amp; they wer askd 2 sit in an aeroplane. Aftr they sat they wer told dat the plane ws made by their students. Dey all hurried out of d plane.. Bt only 1 didnt move... He said:\if it is made by my students
# 3110                                                                                                                                                                                                                                                    Short But Cute : \ Be a good person
# 3145                                                                                                                                                                                                                                                    \SHIT BABE.. THASA BIT MESSED UP.YEH
# 3239                                                                                                                                                                                              A cute thought for friendship: \Its not necessary to share every secret with ur close Frnd
# 3506                                                                                                                                                                                                                                                    Two fundamentals of cool life: \Walk
# 3525                                                                                                                                                                                            \HEY BABE! FAR 2 SPUN-OUT 2 SPK AT DA MO... DEAD 2 DA WRLD. BEEN SLEEPING ON DA SOFA ALL DAY
# 3547                                                                                                                                                                                                               Single line with a big meaning::::: \Miss anything 4 ur \"Best Life\" but
# 3640                                                                                                                                                        You can stop further club tones by replying \STOP MIX\" See my-tone.com/enjoy. html for terms. Club tones cost GBP4.50/week. MFL
# 3758                                                                                                                                                                                                                     GOD ASKED, \What is forgiveness?\" A little child gave lovely reply
# 3788                                                                                                                                                                                                                                                   Are you sure you don't mean \get here
# 3793                                                                                                                                                                                                                                                       Short But Cute: \Be a good person
# 3881                                                                                                                                                                                                                                                       Short But Cute: \Be a good person
# 4130                                                                                                                                                                                                           \Its Ur luck to Love someone. Its Ur fortune to Love the one who Loves U. But
# 4224                                                                                                                                                                     \The world suffers a lot... Not because of the violence of bad people. But because of the silence of good people!\"
# 4454  Storming msg: Wen u lift d phne, u say \HELLO\" Do u knw wt is d real meaning of HELLO?? . . . It's d name of a girl..! . . . Yes.. And u knw who is dat girl?? \"Margaret Hello\" She is d girlfrnd f Grahmbell who invnted telphone... . . . . Moral:One can 4get d name of a person
# 4455                                                                                                                                                                                                                    If you want to mapquest it or something look up \usf dogwood drive\"
# 4570                                                                                                                                                                                                                                                      \CHA QUITEAMUZING THATåÕSCOOL BABE
# 4601                                                                                                                                                                                                                                                          \Hey j! r u feeling any better
# 4668                                                                                                                                                                                                                  When I was born, GOD said, \Oh No! Another IDIOT\". When you were born
# 4859                                                                                                                                                                                                        \Response\" is one of d powerful weapon 2 occupy a place in others 'HEART'... So
# 4992                                                                                                                                                                                                                                                                               \HEY KATE
# 5048                                                                                                                                         Edison has rightly said, \A fool can ask more questions than a wise man can answer\" Now you know why all of us are speechless during ViVa.. GM
# 5079                                                                                                                                                                                                                                                           \Keep ur problems in ur heart
# 5081                                                                                                                                                                 \HI BABE UAWAKE?FEELLIKW SHIT.JUSTFOUND OUT VIA ALETTER THATMUM GOTMARRIED 4thNOV.BEHIND OURBACKS åÐ FUCKINNICE!SELFISH
# 5264  Storming msg: Wen u lift d phne, u say \HELLO\" Do u knw wt is d real meaning of HELLO?? . . . It's d name of a girl..! . . . Yes.. And u knw who is dat girl?? \"Margaret Hello\" She is d girlfrnd f Grahmbell who invnted telphone... . . . . Moral:One can 4get d name of a person
# 5268                                                                                                                                                                                                                                                                                     \ER
#
#                                                                                                                                             Unnamed: 2  \
# 95                                                                                                                                         PO Box 5249
# 281                                                                        the person is definitely special for u..... But if the person is so special
# 444                                                                                            HOWU DOIN? FOUNDURSELF A JOBYET SAUSAGE?LOVE JEN XXX\""
# 671                                                                                                wanted to say hi. HI!!!\" Stop? Send STOP to 62468"
# 710                                                                                                    this wont even start........ Datz confidence.."
# 899                                                                                                                                        PO Box 5249
# 1038                                                                                                                                                GN
# 1127                                                                                                                                          .;-):-D"
# 1266                                                                   just been in bedbut mite go 2 thepub l8tr if uwana mt up?loads a luv Jenxxx.\""
# 1384                                                                                                  bt not his girlfrnd... G o o d n i g h t . . .@"
# 1428                                                                                                                                     I'll come up"
# 1559                                                                                               don't miss ur best life for anything... Gud nyt..."
# 1637                                                                                  just as a shop has to give a guarantee on what they sell. B. G."
# 1669                                                                          But at d end my love compromised me for everything:-(\".. Gud mornin:-)"
# 1675                                                                                   the toughest is acting Happy with all unspoken pain inside..\""
# 1936                                                                                                                               smoke hella weed\""
# 1937                                                                                                                    \" not \"what i need to do.\""
# 1997                        JUST GOT PAYED2DAY & I HAVBEEN GIVEN Aå£50 PAY RISE 4MY WORK & HAVEBEEN MADE PRESCHOOLCO-ORDINATOR 2I AM FEELINGOOD LUV\""
# 2087                    justthought iåÕd sayhey! how u doin?nearly the endof me wk offdam nevamind!We will have 2Hook up sn if uwant m8? loveJen x.\""
# 2170                                                                                        JUST REALLYNEED 2DOCD.PLEASE DONTPLEASE DONTIGNORE MYCALLS
# 2235                                                                                                                      u hav2hear it!c u sn xxxx\""
# 2255                                                                                                                                      I don't mind
# 2406                                                    Dont Come Near My Body..!! Bcoz My Hands May Not Come 2 Wipe Ur Tears Off That Time..!Gud ni8"
# 2791                                                                                         Well there's still a bit left if you guys want to tonight
# 2970                                                                                                   this wont even start........ Datz confidence.."
# 3110                                                                                                        but dont try to prove\" ..... Gud mrng..."
# 3145                                                                                                           SHE SHUDVETOLD U. DID URGRAN KNOW?NEWAY
# 3239                                                                                                        but watever u shared should be true\"...."
# 3506                                                                                          like you are the KING\"...! OR \"Walk like you Dont care
# 3525                                                                                                                                  HAD A COOL NYTHO
# 3547                                                                                               don't miss ur best life for anything... Gud nyt..."
# 3640                                                                                                                       PO Box 1146 MK45 2WT (2/3)"
# 3758                                                  \"It is d wonderful fruit that a tree gives when it is being hurt by a stone.. Good night......"
# 3788                                                                                                                  we made you hold all the weed\""
# 3793                                                                                                       but dont try to prove it..\" .Gud noon...."
# 3881                                                                                                       but dont try to prove it..\" .Gud noon...."
# 4130                                                                    its a miracle to Love a person who can't Love anyone except U...\" Gud nyt..."
# 4224                                                                                                                                    Gud night...."
# 4454                                                                                                  bt not his girlfrnd... G o o d n i g h t . . .@"
# 4455                                                                                                  that's the tiny street where the parking lot is"
# 4570                                                         PROBPOP IN & CU SATTHEN HUNNY 4BREKKIE! LOVE JEN XXX. PSXTRA LRG PORTIONS 4 ME PLEASE \""
# 4601                     hopeSo hunny. i amnow feelin ill & ithink i may have tonsolitusaswell! damn iam layin in bedreal bored. lotsof luv me xxxx\""
# 4668                                                                                                                                          GOD said
# 4859                                                                       always give response 2 who cares 4 U\"... Gud night..swt dreams..take care"
# 4992   HOPE UR OK... WILL GIVE U A BUZ WEDLUNCH. GO OUTSOMEWHERE 4 ADRINK IN TOWN..CUD GO 2WATERSHD 4 A BIT? PPL FROMWRK WILL BTHERE. LOVE PETEXXX.\""
# 5048                                                                                                                                                GN
# 5079                           b'coz nobody will fight for u. Only u &amp; u have to fight for ur self &amp; win the battle. -VIVEKANAND- G 9t.. SD.."
# 5081                                                                                                                               DEVIOUSBITCH.ANYWAY
# 5264                                                                                                  bt not his girlfrnd... G o o d n i g h t . . .@"
# 5268                                                                   ENJOYIN INDIANS AT THE MO..yeP. SaLL gOoD HehE ;> hows bout u shexy? Pete Xx\""
#
#                                       Unnamed: 3  \
# 95                          MK17 92H. 450Ppw 16"
# 281                             why to miss them
# 444                                          NaN
# 671                                          NaN
# 710                                          NaN
# 899                         MK17 92H. 450Ppw 16"
# 1038                                          GE
# 1127                                         NaN
# 1266                                         NaN
# 1384                                         NaN
# 1428                                         NaN
# 1559                                         NaN
# 1637                                         NaN
# 1669                                         NaN
# 1675                                         NaN
# 1936                                         NaN
# 1937                                         NaN
# 1997                                         NaN
# 2087                                         NaN
# 2170    U NO THECD ISV.IMPORTANT TOME 4 2MORO\""
# 2235                                         NaN
# 2255    i wil tolerat.bcs ur my someone..... But
# 2406                                         NaN
# 2791                                         NaN
# 2970                                         NaN
# 3110                                         NaN
# 3145   ILLSPEAK 2 U2MORO WEN IM NOT ASLEEP...\""
# 3239                                         NaN
# 3506          whoever is the KING\"!... Gud nyt"
# 3525                              TX 4 FONIN HON
# 3547                                         NaN
# 3640                                         NaN
# 3758                                         NaN
# 3788                                         NaN
# 3793                                         NaN
# 3881                                         NaN
# 4130                                         NaN
# 4224                                         NaN
# 4454                                         NaN
# 4455                                         NaN
# 4570                                         NaN
# 4601                                         NaN
# 4668            \"OH No! COMPETITION\". Who knew
# 4859                                         NaN
# 4992                                         NaN
# 5048                                          GE
# 5079                                         NaN
# 5081                              IåÕL CALL U\""
# 5264                                         NaN
# 5268                                         NaN
#
#                                                     Unnamed: 4
# 95                                                         NaN
# 281                              just Keep-in-touch\" gdeve.."
# 444                                                        NaN
# 671                                                        NaN
# 710                                                        NaN
# 899                                                        NaN
# 1038                                                   GNT:-)"
# 1127                                                       NaN
# 1266                                                       NaN
# 1384                                                       NaN
# 1428                                                       NaN
# 1559                                                       NaN
# 1637                                                       NaN
# 1669                                                       NaN
# 1675                                                       NaN
# 1936                                                       NaN
# 1937                                                       NaN
# 1997                                                       NaN
# 2087                                                       NaN
# 2170                                                       NaN
# 2235                                                       NaN
# 2255   Never comfort me with a lie\" gud ni8 and sweet dreams"
# 2406                                                       NaN
# 2791                                                       NaN
# 2970                                                       NaN
# 3110                                                       NaN
# 3145                                                       NaN
# 3239                                                       NaN
# 3506                                                       NaN
# 3525                       CALL 2MWEN IM BK FRMCLOUD 9! J X\""
# 3547                                                       NaN
# 3640                                                       NaN
# 3758                                                       NaN
# 3788                                                       NaN
# 3793                                                       NaN
# 3881                                                       NaN
# 4130                                                       NaN
# 4224                                                       NaN
# 4454                                                       NaN
# 4455                                                       NaN
# 4570                                                       NaN
# 4601                                                       NaN
# 4668           one day these two will become FREINDS FOREVER!"
# 4859                                                       NaN
# 4992                                                       NaN
# 5048                                                   GNT:-)"
# 5079                                                       NaN
# 5081                                                       NaN
# 5264                                                       NaN
# 5268                                                       NaN

# %% [markdown]
# #### The Unnamed columns appear to contain message fragments, likely due to encoding or formatting issues during file import. so, concatenating these columns with the main message column and rename the result as message.

# %%
df['message'] = (
    df['v2'].fillna('') + ' ' +
    df['Unnamed: 2'].fillna('') + ' ' +
    df['Unnamed: 3'].fillna('') + ' ' +
    df['Unnamed: 4'].fillna('')
).str.strip()

# %%
df = df[['v1', 'message']]
df.columns = ['label', 'message']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df = df[df['message'].str.strip() != ''].reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %% [markdown]
# ### Encoding

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
df["label"].value_counts()
# Out:
# label
# 0    4825
# 1     747
# Name: count, dtype: int64

# %% [markdown]
# #### Dataset is imbalanced, ~13% of messages are spam, ~87% are ham. Using stratified split

# %%
from sklearn.model_selection import train_test_split

X = df['message']
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# ### Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %% [markdown]
# ### Using Naive bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

model = MultinomialNB()
model.fit(X_train_vec, y_train)

y_pred = model.predict(X_test_vec)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       966
#            1       1.00      0.77      0.87       149
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.97      0.97      1115
#
# [[966   0]
#  [ 35 114]]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight='balanced', max_iter=1000)
model.fit(X_train_vec, y_train)
y_probs = model.predict_proba(X_test_vec)[:, 1]
for t in [0.2, 0.3, 0.4, 0.5]:
    y_pred = (y_probs >= t).astype(int)
    print(f"\nThreshold: {t}")
    print(classification_report(y_test, y_pred))
# Out:
# Threshold: 0.2
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       966
#            1       0.53      0.99      0.69       149
#
#     accuracy                           0.88      1115
#    macro avg       0.77      0.93      0.81      1115
# weighted avg       0.94      0.88      0.90      1115
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       966
#            1       0.77      0.95      0.85       149
#
#     accuracy                           0.96      1115
#    macro avg       0.88      0.95      0.91      1115
# weighted avg       0.96      0.96      0.96      1115
#
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       966
#            1       0.90      0.94      0.92       149
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.96      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
#
#
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       966
#            1       0.95      0.92      0.94       149
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# ### 0.4 threshold has better Recall and precision

# %% [markdown]
# ### Pickled the model for new data prediction

# %%
import joblib

joblib.dump(model, 'spam_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']

# %%
def predict_message(text):
    vect_text = vectorizer.transform([text])
    prob = model.predict_proba(vect_text)[0][1]
    return "Spam" if prob >= 0.4 else "Ham", prob

# %%
msg = "Free entry in 2 a weekly competition..."
label, confidence = predict_message(msg)
print(f"{label} ({confidence:.2f} confidence)")
# Out:
# Spam (0.61 confidence)
